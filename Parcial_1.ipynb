# %% [markdown]
# # Parcial 1 Minería de datos
# ## Carlos Fernando Gonzalzez Sarmiento

# %%
# !pip install dfply
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 612 kB 7.4 MB/s
# ...

# %%
import pandas as pd
import numpy as np
import csv
from dfply import *

# %%
pd.set_option('display.max_columns', None) #Mostrar todas las columnas

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/prof-tatiana-gutierrez/DatosMD/master/student-mat.csv',
    sep = ";")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %% [markdown]
# # Punto 1

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ## R\\\
#
# Basandonos en los anteriores codigos, no existe ningun valor vacío o nulo para alguna de las variables de la base.

# %% [markdown]
# # Punto 2

# %%
(df['address']=='U').sum()
# Out:
# 307

# %%
(df['address']=='R').sum()
# Out:
# 88

# %%
(df['address']=='R').sum()+(df['address']=='U').sum()
# Out:
# 395

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
a=df['address']=='R'

# %%
df[a].shape
# Out:
# (88, 33)

# %%
df[a]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 24      GP   F   15       R     GT3       T     2     4  services   health
# 32      GP   M   15       R     GT3       T     4     3   teacher  at_home
# 37      GP   M   16       R     GT3       A     4     4     other  teacher
# 38      GP   F   15       R     GT3       T     3     4  services   health
# 39      GP   F   15       R     GT3       T     2     2   at_home    other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...      ...
# 385     MS   F   18       R     GT3       T     2     2   at_home    other
# 386     MS   F   18       R     GT3       T     4     4   teacher  at_home
# 387     MS   F   19       R     GT3       T     2     3  services    other
# 392     MS   M   21       R     GT3       T     1     1     other    other
# 393     MS   M   18       R     LE3       T     3     2  services    other
#
# ...

# %%
Base88 = (df>>
  mask(X.sex=='M',X.address=='R'))
Base88.shape# Colegio Mousinho con internet
# Out:
# (44, 33)

# %%
df2=df[a]
(df2['sex']=='M').sum()
# Out:
# 44

# %% [markdown]
# ## R\\\
#
# Para la zona urbana viven 307 estudiantes, para la zona rural viven 88 estudiantes.
#
# 44 estudiantes rurales son hombres.

# %% [markdown]
# # Punto 3

# %%
(df2['absences']>5).sum()
# Out:
# 38

# %%
a2=df2['absences']>5
a2
# Out:
# 24     False
# 32     False
# 37      True
# 38     False
# 39      True
#        ...
# 385    False
# 386     True
# 387    False
# 392    False
# 393    False
# Name: absences, Length: 88, dtype: bool

# %%
Base2 = (df >>
 mask(X.sex=='M',X.address=='R',X.absences>5))

# %%
Base2.shape
# Out:
# (18, 33)

# %% [markdown]
# ## R\\\
#
# 38 estudiantes de la zona rural tienen mas de 5 fallas.
#
# Y 18 de ellos son hombres

# %% [markdown]
# # Punto 4

# %%
Base3 = (df >>
  select(X.school,X.G3,X.internet))
Base3
# Out:
#     school  G3 internet
# 0       GP   6       no
# 1       GP   6      yes
# 2       GP  10      yes
# 3       GP  15      yes
# 4       GP  10       no
# ..     ...  ..      ...
# 390     MS   9       no
# 391     MS  16      yes
# 392     MS   7       no
# 393     MS  10      yes
# 394     MS   9      yes
#
# [395 rows x 3 columns]

# %%
Base4 = (Base3 >>
  mask(X.school=='GP',X.internet=='yes'))
Base4['G3'].mean()# Colegio Gabriel Pereira con internet
# Out:
# 10.632996632996633

# %%
Base5 = (Base3 >>
  mask(X.school=='GP',X.internet=='no'))
Base5['G3'].mean()# Colegio Gabriel Pereira sin internet
# Out:
# 9.673076923076923

# %%
Base6 = (Base3 >>
  mask(X.school=='MS',X.internet=='yes'))
Base6['G3'].mean()# Colegio Mousinho con internet
# Out:
# 10.46875

# %%
Base7 = (Base3 >>
  mask(X.school=='MS',X.internet=='no'))
Base7['G3'].mean()# Colegio Mousinho sin internet
# Out:
# 8.428571428571429

# %% [markdown]
# ## R\\\
#
# La media de las notas de matematicas de los estudiantes del Colegio Gabriel Pereira que poseen internet, es: 10.632996632996633.
#
# La media de las notas de matematicas de los estudiantes del Colegio Gabriel Pereira que no poseen internet, es: 9.673076923076923.
#
# La media de las notas de matematicas de los estudiantes del Colegio Mousinho que poseen internet, es: 10.46875.
#
# La media de las notas de matematicas de los estudiantes del Colegio Mousinho que no poseen internet, es: 8.428571428571429.

# %% [markdown]
# # Punto 5

# %%
Base8 = (df >>
 mutate(
   calf_ttl = X.G1*0.3+X.G2*0.3+X.G3*0.4

 ))
Base8.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
Base8.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
Base8['calf_ttl'].median()
# Out:
# 10.7

# %% [markdown]
# ## R\\\
#
# La media calificacion total es: 10.652911
#
# La mediana calificacion total es: 10.7
#
# La mínima calificación total es: 1.2
#
# La máxima calificación total es: 19.4

# %% [markdown]
# # Punto 6

# %% [markdown]
# En mi opinión realizaría un análisis de regresión, para predecir, usaría la variable de G3, que corresponde a la nota de tercer corte, ya que es la última y a partir de variables como las notas de segundo y primer corte, además de a que colegio pertenece y entre otras, se podría predecir la ultima nota.
